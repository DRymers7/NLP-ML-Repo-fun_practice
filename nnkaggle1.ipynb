# %%
import pandas as pd
df = pd.read_csv('train_features.csv')
df.head()
# Out:
#    building_id            timestamp  meter_reading  anomaly  site_id  \
# 0            1  2016-01-01 00:00:00            NaN        0        0
# 1           32  2016-01-01 00:00:00            NaN        0        0
# 2           41  2016-01-01 00:00:00            NaN        0        0
# 3           55  2016-01-01 00:00:00            NaN        0        0
# 4           69  2016-01-01 00:00:00            NaN        0        0
#
#   primary_use  square_feet  year_built  floor_count  air_temperature  ...  \
# 0   Education         2720         104            0             19.4  ...
# 1      Office        48392         105            0             19.4  ...
# 2      Office        93860          68            0             19.4  ...
# 3      Office        16726         111            0             19.4  ...
# 4     Parking       387638         100            0             19.4  ...
#
#    gte_meter  gte_meter_hour  gte_meter_weekday  gte_meter_month  \
# 0      4.116           3.981              4.146             4.12
# 1      4.116           3.981              4.146             4.12
# 2      4.116           3.981              4.146             4.12
# 3      4.116           3.981              4.146             4.12
# 4      4.116           3.981              4.146             4.12
#
#    gte_meter_building_id  gte_meter_primary_use  gte_meter_site_id  \
# 0                  3.569                  4.489              4.079
# 1                  4.513                  4.211              4.079
# 2                  4.108                  4.211              4.079
# 3                  3.506                  4.211              4.079
# 4                  3.035                  3.623              4.079
#
#    gte_meter_building_id_hour  gte_meter_building_id_weekday  \
# 0                       3.554                          3.538
# 1                       4.128                          4.579
# 2                       4.103                          4.140
# 3                       3.308                          3.565
# 4                       3.892                          3.090
#
#    gte_meter_building_id_month
# 0                        3.845
# 1                        4.317
# 2                        4.114
# 3                        3.813
# 4                        3.577
#
# [5 rows x 57 columns]

# %%
#Creating NN on training data
df['meter_reading'].fillna((df['meter_reading'].mean()), inplace=True)

# %%
df.head()
# Out:
#    building_id            timestamp  meter_reading  anomaly  site_id  \
# 0            1  2016-01-01 00:00:00     179.901838        0        0
# 1           32  2016-01-01 00:00:00     179.901838        0        0
# 2           41  2016-01-01 00:00:00     179.901838        0        0
# 3           55  2016-01-01 00:00:00     179.901838        0        0
# 4           69  2016-01-01 00:00:00     179.901838        0        0
#
#   primary_use  square_feet  year_built  floor_count  air_temperature  ...  \
# 0   Education         2720         104            0             19.4  ...
# 1      Office        48392         105            0             19.4  ...
# 2      Office        93860          68            0             19.4  ...
# 3      Office        16726         111            0             19.4  ...
# 4     Parking       387638         100            0             19.4  ...
#
#    gte_meter  gte_meter_hour  gte_meter_weekday  gte_meter_month  \
# 0      4.116           3.981              4.146             4.12
# 1      4.116           3.981              4.146             4.12
# 2      4.116           3.981              4.146             4.12
# 3      4.116           3.981              4.146             4.12
# 4      4.116           3.981              4.146             4.12
#
#    gte_meter_building_id  gte_meter_primary_use  gte_meter_site_id  \
# 0                  3.569                  4.489              4.079
# 1                  4.513                  4.211              4.079
# 2                  4.108                  4.211              4.079
# 3                  3.506                  4.211              4.079
# 4                  3.035                  3.623              4.079
#
#    gte_meter_building_id_hour  gte_meter_building_id_weekday  \
# 0                       3.554                          3.538
# 1                       4.128                          4.579
# 2                       4.103                          4.140
# 3                       3.308                          3.565
# 4                       3.892                          3.090
#
#    gte_meter_building_id_month
# 0                        3.845
# 1                        4.317
# 2                        4.114
# 3                        3.813
# 4                        3.577
#
# [5 rows x 57 columns]

# %%
#Classes unbalanced
count_norm = len(df[df['anomaly']==0])
count_anom = len(df[df['anomaly']==1])
pct_norm = count_norm/(count_norm+count_anom)
print('percentage of normal instances is ', pct_norm*100)
pct_anom = count_anom/(count_anom+count_norm)
print('percentage of anomaly instances is ', pct_anom*100)
# Out:
# percentage of normal instances is  97.86818360051535
# percentage of anomaly instances is  2.131816399484651

# %%
#Convert categorical dtypes
cat_columns = df.select_dtypes(['object']).columns
df[cat_columns] = df[cat_columns].apply(lambda x: pd.factorize(x)[0])

# %%
cols = df.columns.tolist()
y = df.iloc[:,3:4]
y.shape
# Out:
# (1749494, 1)

# %%
df.drop(['anomaly'], axis=1, inplace=True)
x = df.iloc[:,0:56]
x.shape
# Out:
# (1749494, 56)

# %%
#Oversampling anomaly instances to create more accurate thresholds for network

from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)
columns = x_train.columns

# %%
#Oversampling with smote
oversample = SMOTE()
x1, y1 = oversample.fit_resample(x_train, y_train)
counter = Counter(y1)
print(counter)
# Out:
# Counter({'anomaly': 1})

# %%
y1.value_counts()
# Out:
# anomaly
# 0          1147121
# 1          1147121
# dtype: int64

# %%
#Scaling feature data for NN

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
#Scale oversampled data

X_train = scaler.fit_transform(x1)
X_test = scaler.fit_transform(x_test)

# %%
from tensorflow import keras

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %%
from keras import callbacks

# %%
#Early stopping callback to help overfit 
earlystopping = callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5, restore_best_weights=True)

# %%
#Neural network for anomalies in training data - simple to start
model = Sequential()
model.add(Dense(1024, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.25))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.35))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 1024)              58368
#
#  dropout_9 (Dropout)         (None, 1024)              0
#
#  dense_19 (Dense)            (None, 512)               524800
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_20 (Dense)            (None, 256)               131328
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_21 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 714,753
# Trainable params: 714,753
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(X_train, y1, validation_data=(X_test, y_test), epochs=100, batch_size=len(X_train[1]), callbacks=[earlystopping])
# Out:
# Epoch 1/100
# 40969/40969 [==============================] - 250s 6ms/step - loss: 0.2622 - accuracy: 0.8866 - val_loss: 0.1144 - val_accuracy: 0.9620
# Epoch 2/100
# 40969/40969 [==============================] - 254s 6ms/step - loss: 0.1627 - accuracy: 0.9350 - val_loss: 0.1335 - val_accuracy: 0.9484
# Epoch 3/100
# 40969/40969 [==============================] - 256s 6ms/step - loss: 0.1297 - accuracy: 0.9496 - val_loss: 0.1328 - val_accuracy: 0.9501
# Epoch 4/100
# 40969/40969 [==============================] - 247s 6ms/step - loss: 0.1130 - accuracy: 0.9568 - val_loss: 0.0969 - val_accuracy: 0.9642
# Epoch 5/100
# 40969/40969 [==============================] - 231s 6ms/step - loss: 0.1016 - accuracy: 0.9617 - val_loss: 0.1100 - val_accuracy: 0.9609
# Epoch 6/100
# 40969/40969 [==============================] - 231s 6ms/step - loss: 0.0964 - accuracy: 0.9639 - val_loss: 0.0692 - val_accuracy: 0.9752
# Epoch 7/100
# 40969/40969 [==============================] - 231s 6ms/step - loss: 0.0910 - accuracy: 0.9664 - val_loss: 0.0637 - val_accuracy: 0.9769
# Epoch 8/100
# 40969/40969 [==============================] - 230s 6ms/step - loss: 0.0848 - accuracy: 0.9688 - val_loss: 0.0639 - val_accuracy: 0.9773
# Epoch 9/100
# 40969/40969 [==============================] - 242s 6ms/step - loss: 0.0816 - accuracy: 0.9702 - val_loss: 0.0738 - val_accuracy: 0.9747
# Epoch 10/100
# 40969/40969 [==============================] - 251s 6ms/step - loss: 0.0782 - accuracy: 0.9716 - val_loss: 0.0602 - val_accuracy: 0.9791
# Epoch 11/100
# 40969/40969 [==============================] - 253s 6ms/step - loss: 0.0740 - accuracy: 0.9733 - val_loss: 0.0638 - val_accuracy: 0.9787
# Epoch 12/100
# 40969/40969 [==============================] - 319s 8ms/step - loss: 0.0712 - accuracy: 0.9745 - val_loss: 0.0585 - val_accuracy: 0.9783
# Epoch 13/100
# 40969/40969 [==============================] - 254s 6ms/step - loss: 0.0679 - accuracy: 0.9758 - val_loss: 0.0544 - val_accuracy: 0.9813
# Epoch 14/100
# 40969/40969 [==============================] - 257s 6ms/step - loss: 0.0668 - accuracy: 0.9763 - val_loss: 0.0626 - val_accuracy: 0.9768
# Epoch 15/100
# 40969/40969 [==============================] - 252s 6ms/step - loss: 0.0663 - accuracy: 0.9766 - val_loss: 0.0652 - val_accuracy: 0.9771
# Epoch 16/100
# 40969/40969 [==============================] - 256s 6ms/step - loss: 0.0647 - accuracy: 0.9772 - val_loss: 0.0489 - val_accuracy: 0.9831
# Epoch 17/100
# 40969/40969 [==============================] - 252s 6ms/step - loss: 0.0690 - accuracy: 0.9757 - val_loss: 0.0615 - val_accuracy: 0.9780
# Epoch 18/100
# 40969/40969 [==============================] - 253s 6ms/step - loss: 0.0688 - accuracy: 0.9757 - val_loss: 0.0624 - val_accuracy: 0.9786
# Epoch 19/100
# 40969/40969 [==============================] - 252s 6ms/step - loss: 0.0681 - accuracy: 0.9760 - val_loss: 0.0546 - val_accuracy: 0.9808
# Epoch 20/100
# 40969/40969 [==============================] - 253s 6ms/step - loss: 0.0668 - accuracy: 0.9764 - val_loss: 0.0674 - val_accuracy: 0.9761
# Epoch 21/100
# 40969/40969 [==============================] - 253s 6ms/step - loss: 0.0638 - accuracy: 0.9776 - val_loss: 0.0488 - val_accuracy: 0.9832
# Epoch 22/100
# 40969/40969 [==============================] - 253s 6ms/step - loss: 0.0629 - accuracy: 0.9782 - val_loss: 0.0484 - val_accuracy: 0.9821
# Epoch 23/100
# 40969/40969 [==============================] - 254s 6ms/step - loss: 0.0651 - accuracy: 0.9773 - val_loss: 0.0785 - val_accuracy: 0.9723
# Epoch 24/100
# 40969/40969 [==============================] - 254s 6ms/step - loss: 0.0646 - accuracy: 0.9776 - val_loss: 0.0656 - val_accuracy: 0.9762
# Epoch 25/100
# 40969/40969 [==============================] - 252s 6ms/step - loss: 0.0658 - accuracy: 0.9771 - val_loss: 0.0543 - val_accuracy: 0.9825
# Epoch 26/100
# 40969/40969 [==============================] - 253s 6ms/step - loss: 0.0630 - accuracy: 0.9781 - val_loss: 0.0604 - val_accuracy: 0.9802
# Epoch 27/100
# 40969/40969 [==============================] - 258s 6ms/step - loss: 0.0631 - accuracy: 0.9783 - val_loss: 0.0508 - val_accuracy: 0.9828

# %%
from sklearn.metrics import confusion_matrix

y_predicted = model.predict(X_test) > 0.5
mat = confusion_matrix(y_test, y_predicted)
labels = ['Normal', 'Anomaly']
# Out:
# 18042/18042 [==============================] - 27s 1ms/step

# %%
mat
# Out:
# array([[555968,   9109],
#        [  1200,  11057]], dtype=int64)

# %%
#Saving model
from pathlib import Path
model_structure = model.to_json()
f = Path('model_structure_anom.json')
f.write_text(model_structure)

#Saving weights
model.save_weights('model_weights_anom.h5')

# %%
#Importing test data

import pandas as pd
df = pd.read_csv('test_features.csv')
df.head()
# Out:
#    row_id  building_id            timestamp  meter_reading  site_id  \
# 0       0           18  2016-01-01 00:00:00            NaN        0
# 1       1           19  2016-01-01 00:00:00            NaN        0
# 2       2           26  2016-01-01 00:00:00            NaN        0
# 3       3           38  2016-01-01 00:00:00            NaN        0
# 4       4           39  2016-01-01 00:00:00            NaN        0
#
#   primary_use  square_feet  year_built  floor_count  air_temperature  ...  \
# 0   Education       111891          96            0             19.4  ...
# 1      Office        18717         104            0             19.4  ...
# 2      Office        26953         105            0             19.4  ...
# 3      Office        12769         113            0             19.4  ...
# 4      Office        64619          69            0             19.4  ...
#
#    gte_meter  gte_meter_hour  gte_meter_weekday  gte_meter_month  \
# 0      4.116           3.981              4.146             4.12
# 1      4.116           3.981              4.146             4.12
# 2      4.116           3.981              4.146             4.12
# 3      4.116           3.981              4.146             4.12
# 4      4.116           3.981              4.146             4.12
#
#    gte_meter_building_id  gte_meter_primary_use  gte_meter_site_id  \
# 0                  6.389                  4.489              4.079
# 1                  4.098                  4.211              4.079
# 2                  3.785                  4.211              4.079
# 3                  4.961                  4.211              4.079
# 4                  4.584                  4.211              4.079
#
#    gte_meter_building_id_hour  gte_meter_building_id_weekday  \
# 0                       6.370                          6.392
# 1                       4.031                          4.125
# 2                       3.046                          3.804
# 3                       4.949                          4.964
# 4                       4.472                          4.600
#
#    gte_meter_building_id_month
# 0                        5.254
# 1                        4.109
# 2                        3.953
# 3                        4.541
# 4                        4.352
#
# [5 rows x 57 columns]

# %%
df['meter_reading'].fillna((df['meter_reading'].mean()), inplace=True)

# %%
cat_columns = df.select_dtypes(['object']).columns
df[cat_columns] = df[cat_columns].apply(lambda x: pd.factorize(x)[0])

# %%
x = df.iloc[:,0:56]
x.shape
# Out:
# (1800567, 56)

# %%
x
# Out:
#           row_id  building_id  timestamp  meter_reading  site_id  primary_use  \
# 0              0           18          0     174.987865        0            0
# 1              1           19          0     174.987865        0            1
# 2              2           26          0     174.987865        0            1
# 3              3           38          0     174.987865        0            1
# 4              4           39          0     174.987865        0            1
# ...          ...          ...        ...            ...      ...          ...
# 1800562  1800562         1320       8783      74.552000       14            5
# 1800563  1800563         1321       8783     584.000000       14            5
# 1800564  1800564         1322       8783     131.596000       14            5
# 1800565  1800565         1384       8783       1.200000       15            0
# 1800566  1800566         1425       8783      19.325000       15           11
#
#          square_feet  year_built  floor_count  air_temperature  ...  \
# 0             111891          96            0             19.4  ...
# 1              18717         104            0             19.4  ...
# 2              26953         105            0             19.4  ...
# 3              12769         113            0             19.4  ...
# 4              64619          69            0             19.4  ...
# ...              ...         ...          ...              ...  ...
# 1800562        34565         255            0            -29.9  ...
# 1800563       370024         255            0            -29.9  ...
# 1800564       166489         255            0            -29.9  ...
# 1800565        56969          67            0            -29.9  ...
# 1800566         4071          90            0            -29.9  ...
#
#          gte_site_id  gte_meter  gte_meter_hour  gte_meter_weekday  \
# 0              4.703      4.116           3.981              4.146
# 1              4.703      4.116           3.981              4.146
# 2              4.703      4.116           3.981              4.146
# 3              4.703      4.116           3.981              4.146
# 4              4.703      4.116           3.981              4.146
# ...              ...        ...             ...                ...
# 1800562        5.148      4.116           4.009              4.012
# 1800563        5.148      4.116           4.009              4.012
# 1800564        5.148      4.116           4.009              4.012
# 1800565        4.331      4.116           4.009              4.012
# 1800566        4.331      4.116           4.009              4.012
#
#          gte_meter_month  gte_meter_building_id  gte_meter_primary_use  \
# 0                  4.120                  6.389                  4.489
# 1                  4.120                  4.098                  4.211
# 2                  4.120                  3.785                  4.211
# 3                  4.120                  4.961                  4.211
# 4                  4.120                  4.584                  4.211
# ...                  ...                    ...                    ...
# 1800562            4.056                  4.810                  3.532
# 1800563            4.056                  6.013                  3.532
# 1800564            4.056                  4.824                  3.532
# 1800565            4.056                  0.848                  4.489
# 1800566            4.056                  3.972                  4.450
#
#          gte_meter_site_id  gte_meter_building_id_hour  \
# 0                    4.079                       6.370
# 1                    4.079                       4.031
# 2                    4.079                       3.046
# 3                    4.079                       4.949
# 4                    4.079                       4.472
# ...                    ...                         ...
# 1800562              4.710                       4.987
# 1800563              4.710                       6.142
# 1800564              4.710                       4.823
# 1800565              4.188                       0.810
# 1800566              4.188                       2.794
#
#          gte_meter_building_id_weekday
# 0                                6.392
# 1                                4.125
# 2                                3.804
# 3                                4.964
# 4                                4.600
# ...                                ...
# 1800562                          4.751
# 1800563                          5.958
# 1800564                          4.803
# 1800565                          0.817
# 1800566                          3.810
#
# [1800567 rows x 56 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
X_pred = scaler.fit_transform(x)

# %%
X_pred
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         6.90686275e-01, 8.08940159e-01, 8.15058480e-01],
#        [5.55380919e-07, 7.10732054e-04, 0.00000000e+00, ...,
#         6.90686275e-01, 4.71665465e-01, 4.83625731e-01],
#        [1.11076184e-06, 5.68585643e-03, 0.00000000e+00, ...,
#         6.90686275e-01, 3.29632300e-01, 4.36695906e-01],
#        ...,
#        [9.99998889e-01, 9.26794598e-01, 1.00000000e+00, ...,
#         1.00000000e+00, 5.85868782e-01, 5.82748538e-01],
#        [9.99999445e-01, 9.70859986e-01, 1.00000000e+00, ...,
#         7.44117647e-01, 7.20980534e-03, 0.00000000e+00],
#        [1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#         7.44117647e-01, 2.93294881e-01, 4.37573099e-01]])

# %%
predictions = (model.predict(X_pred) > 0.5).astype('int32')
print(predictions)
# Out:
# 56268/56268 [==============================] - 80s 1ms/step
# [[0]
#  [0]
#  [0]
#  ...
#  [0]
#  [0]
#  [0]]

# %%
predictions.shape
# Out:
# (1800567, 1)

# %%
#Converting predictions and rows to array for concatentation
row_id = df.iloc[:,0:1].values

# %%
predictions
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
row_id
# Out:
# array([[      0],
#        [      1],
#        [      2],
#        ...,
#        [1800564],
#        [1800565],
#        [1800566]], dtype=int64)

# %%
#Concatenating the array
import numpy as np
pred1 = np.concatenate((row_id, predictions), axis=1)

# %%
pred1
# Out:
# array([[      0,       0],
#        [      1,       0],
#        [      2,       0],
#        ...,
#        [1800564,       0],
#        [1800565,       0],
#        [1800566,       0]], dtype=int64)

# %%
pred_df = pd.DataFrame(pred1, columns=['row_id', 'anomaly'])

# %%
#Checking results
pred_df
# Out:
#           row_id  anomaly
# 0              0        0
# 1              1        0
# 2              2        0
# 3              3        0
# 4              4        0
# ...          ...      ...
# 1800562  1800562        0
# 1800563  1800563        0
# 1800564  1800564        0
# 1800565  1800565        0
# 1800566  1800566        0
#
# [1800567 rows x 2 columns]

# %%
#Converting to csv
pred_df.to_csv('Submission_B1', index=False)

# %%
pred_df['anomaly'].value_counts()
# Out:
# 0    1797412
# 1       3155
# Name: anomaly, dtype: int64
